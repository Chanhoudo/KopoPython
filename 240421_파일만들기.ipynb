# %%
with open("test.csv", 'w', encoding = 'utf-8') as f:
  f.write("안녕하세요~\n")
  f.write("예진누나~\n")
  f.write("사랑함당\n")
  f.write("가나다라마바사아자차카타파하")

# %%
with open ("test.csv", 'r', encoding = 'utf-8') as f:
  #print(f.read(6))
  #print(f.read(6))
  #s1 = f.read()
  #print(s1)
  #print(f.read())

  f.seek(0)
  i = 0
  for line in f:
    i += 1
    print(i, end = '')
    print(line, end = ' ')

  f.seek(0)
  print('\n',f.readline(), end = '') #readline() 한줄의 데이터만 가져옴
  print(f.readlines()) #readlines() 한줄 한줄씩 리스트에 담아서 저장


  f.seek(0)
  print("\n\nlines for문 작동")
  for line in f.readlines():
    print(line, end='')

  f.close()


#with open("test.txt", 'w', encoding = 'utf-8') as f:
#  print(f.read(4))
# Out:
# 1안녕하세요~
#  2예진누나~
#  3사랑함당
#  4가나다라마바사아자차카타파하
#  안녕하세요~
# ['예진누나~\n', '사랑함당\n', '가나다라마바사아자차카타파하']
#
#
# lines for문 작동
# 안녕하세요~
# 예진누나~
# 사랑함당
# 가나다라마바사아자차카타파하

# %%
# Out:
# 0

# %%
with open("test.txt", 'w', encoding = 'utf-8') as f:
  f.write("장원영사기린스드메론")
  #영사 -> a
  #스드 -> b

# %%
with open("test.txt", 'r', encoding = 'utf-8') as f:
  lines = f.readlines()
  f.close()



temp = ''
change_index = []



for line_i in range(len(lines)):
  for c_i in range(len(lines[line])):
    temp += lines[line_i][c_i]
    if len(temp) > 2:
      temp = temp[1] + temp[2]
    if temp == '영사':
      a_i = [line_i-1, c_i-1,'a']
      change_index.append(a_i)
    elif temp == '스드':
      a_i = [line_i-1, c_i-1,'b']
      change_index.append(a_i)

lines_copy = ''
change_check = False
for i in range(len(lines)):
  for j in range(len(lines[i])):
    change_check = False
    for k in change_index:
      if k[0] == i and k[1] == j:




with open("test.txt", 'w', encoding = 'utf-8') as f:
  f.wirte(lines)
# Out:
# ['장원영사기린스드메론']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-e4d7459aab36> in <cell line: 25>()
#      24
#      25 with open("test.txt", 'w', encoding = 'utf-8') as f:
# ---> 26   f.wirte(lines)
#      27
#      28
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'wirte'

# %%
import os
import random

# %%
# B 폴더 생성
path = 'B'

if not os.path.isdir(path):
  os.mkdir(path)

# %%
# B폴더안에 a.txt 생성
str1  = ''

with open('B/a.txt','w',encoding = 'utf-8') as  f:
  for i in range(5):
    str1 += str(random.randint(1,10)) + ' '
  f.write(str1)
