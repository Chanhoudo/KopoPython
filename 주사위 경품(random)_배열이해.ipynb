# %%
import random

dice_dic = {1:"벤츠", 2:"호텔", 3:"100만원", 4:"꽝", 5:"유람선", 6:"발레니 30"}
price = int(input("지갑에 있는 현찰 입력(원 단위): "))

while True:
  answer = input("주사위를 던지시겠습니까(회 당 5000원)?(Y,N): ")

  if answer == 'Y':
    if price < 5000:
      print("돈이 부족하시네요 ㅠ")
      break
    dice = random.randint(1,6)
    print(dice_dic[dice], "당첨!!")
    price -= 5000

  elif answer == 'N':
    print("다음에 또 만나요~")
    break

  else:
    print("(Y,N)만 입력해주세요..")
# Out:
# 지갑에 있는 현찰 입력(원 단위): 20000
# 주사위를 던지시겠습니까(회 당 5000원)?(Y,N)Y
# 100만원 당첨!!
# 주사위를 던지시겠습니까(회 당 5000원)?(Y,N)Y
# 호텔 당첨!!
# 주사위를 던지시겠습니까(회 당 5000원)?(Y,N)Y
# 벤츠 당첨!!
# 주사위를 던지시겠습니까(회 당 5000원)?(Y,N)Y
# 꽝 당첨!!
# 주사위를 던지시겠습니까(회 당 5000원)?(Y,N)Y
# 돈이 부족하시네요 ㅠ

# %%
num1 = int(input("숫자 1 입력: "))
num2 = int(input("숫자 2 입력: "))

if num1 < num2:
  temp = num1
  num1 = num2
  num2 = temp

print(num1 - num2)
# Out:
# 숫자 1 입력: 3
# 숫자 2 입력: 5
# 2

# %%
import random

# %%
dice_two_dic = {1 : {1: "라면",   2:"호텔",     3:"100만원", 4:"꽝",     5:"유람선", 6:"발레니 30"},
                2 : {1: "경품1",  2: "경품2",   3: "경품3",  4:"경품4",  5:"경품5",  6:"경품6"},
                3 : {1: "경품7",  2: "경품8" ,  3: "경품9",  4:"경품10", 5:"경품11", 6:"경품12"},
                4 : {1: "경품13", 2: "경품14" , 3: "경품15", 4:"경품16", 5:"경품17", 6:"경품18"},
                5 : {1: "경품19", 2: "경품20" , 3: "경품21", 4:"경품22", 5:"경품23", 6:"경품24"},
                6 : {1: "경품25", 2: "경품26" , 3: "경품27", 4:"경품28", 5:"경품29", 6:"경품30"}}

go1 = input("준비가 되시면 주사위를 굴려주세요~ (아무거나 입력하시고 엔터를 눌러주세요!)")
dice1 = random.randint(1, 6)

print("\n첫번째 주사위의 값은", dice1, "\n=================================경품들 목록리스트===============================")
print(dice_two_dic[dice1])
print("=================================================================================\n")

go2 = input("한번 더 주사위를 굴려주세요~ (아무거나 입력하시고 엔터를 눌러주세요!)")
dice2 = random.randint(1, 6)

print("\n====================================== 당첨! ====================================")
print("-------------------------------------",dice_two_dic[dice1][dice2],"------------------------------------")
print("=================================================================================")
# Out:
# 준비가 되시면 주사위를 굴려주세요~ (아무거나 입력하시고 엔터를 눌러주세요!)
#
# 첫번째 주사위의 값은 3
# =================================경품들 목록리스트===============================
# {1: '경품7', 2: '경품8', 3: '경품9', 4: '경품10', 5: '경품11', 6: '경품12'}
# ...
#
# 한번 더 주사위를 굴려주세요~ (아무거나 입력하시고 엔터를 눌러주세요!)
#
# ====================================== 당첨! ====================================
# ------------------------------------- 경품10 ------------------------------------
# ...

# %%
m = 4620

a = int(m / 1000)
b = int((m % 1000) / 500)
c = int((m % 500) / 100)
d = int((m % 100) / 10)


print("천원의 갯수:", a, "오백원의 갯수:", b, "백원의 갯수:", c, "십원의 갯수:", d)
# Out:
# 천원의 갯수: 4 오백원의 갯수: 1 백원의 갯수: 1 십원의 갯수: 2

# %%
import random

# %%
marry_site = {"남":{"박사" : {"1억": 8, "8천":7, "7천":6, "5천":5, "3천":4},
                    "석사" : {"1억": 7, "8천":6, "7천":5, "5천":4, "3천":3},
                    "학사" : {"1억": 6, "8천":5, "7천":4, "5천":3, "3천":2}},
              "여":{"박사" : {"1억": 9, "8천":8, "7천":7, "5천":6, "3천":5},
                    "석사" : {"1억": 8, "8천":7, "7천":6, "5천":5, "3천":4},
                    "학사" : {"1억": 7, "8천":6, "7천":5, "5천":4, "3천":3}}}

# random_gender = random.choice(list(marry_site.keys()))
# random_school = random.choice(list(marry_site[random_gender].keys()))
# random_salary = random.choice(list(marry_site[random_gender][random_school].keys()))

# print("===================================")
# print("랜덤한 정보의 등급은: ", marry_site[random_gender][random_school][random_salary])
# print("===================================")

salary_score = {"1억": 5, "8천":4, "7천":3, "5천":2, "3천":1}

while True:
  gender = input("성별을 입력해주세요(남,여): ")
  if gender in marry_site.keys():
    break
  print("(남 또는 여)를 입력해주세요.")

while True:
  school = input("학위를 입력해주세요(박사, 석사, 학사): ")
  if school in marry_site[gender].keys():
    break
  print("박사 또는 석사 또는 학사만 입력해주세요.")

while True:
  salary = input("연봉을 입력해주세요(1억, 8천, 7천, 5천, 3천): ")
  if salary in marry_site[gender][school].keys():
    break
  print("1억, 8천, 7천, 5천, 3천 중 가장 가까운 연봉을 적어주세요.")



score = marry_site[gender][school][salary]

print("입력하신 정보의 등급은: ", score)
# Out:
# 성별을 입력해주세요(남,여): 여
# 학위를 입력해주세요(박사, 석사, 학사): 박사
# 연봉을 입력해주세요(1억, 8천, 7천, 5천, 3천): 1억
# 입력하신 정보의 등급은:  9
