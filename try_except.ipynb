# %%
import sys

# %%
random_List = ['a',0,2]

for entry in random_List:
  try:
    print("The entry is", entry)
    r = 1/int(entry)
    break
  except:
    print("Oops!", sys.exc_info()[0], "occurred.")
    print("Next entry.")
    print()

print(entry, "is", r)
# Out:
# The entry is a
# Oops! <class 'ValueError'> occurred.
# Next entry.
#
# The entry is 0
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
#
# The entry is 2
# 2 is 0.5

# %%
for entry in random_List:
  r = 1/int(entry)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b7c136a0d908> in <cell line: 1>()
#       1 for entry in random_List:
# ----> 2   r = 1/int(entry)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
try:
  num = int(input("Enter number: "))
  assert num % 2 == 0, 'Error message of assert'
except:
  print("Not Enven")
else:
  reciprocal = 1/num
  print(reciprocal)
# Out:
# Enter number: 2
# 0.5
